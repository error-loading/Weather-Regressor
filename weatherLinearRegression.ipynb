# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# # Enter your data

# %%
df = pd.read_csv(r'./fwdtemperaturedatasets/weatherHistory_1.5k_OG.csv')

# %% [markdown]
# # Input and Output

# %%
x = df.iloc [:,1:]
y = df.iloc[:,0]

# %% [markdown]
# # Split your data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# # Create Machine Learning Model

# %%
lr = LinearRegression()

# %% [markdown]
# # Train your Machine Learning Model

# %%
model = lr.fit(x_train, y_train)

# %% [markdown]
# # Calculate the Accuracy

# %%
print('Accuracy: ', round(model.score(x_test, y_test) * 100, 2))
# Out:
# Accuracy:  98.96

# %% [markdown]
# # Predict Values

# %%
predict = lr.predict([['21','0.6','15','180', '11', '1005']])
print(predict)
# Out:
# [21.0137992]
# /Users/gsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Users/gsingh/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)

# %% [markdown]
# # Error

# %%
mse = mean_squared_error(y_test, lr.predict(x_test))
print(mse)
# Out:
# 0.33650581573331845

# %% [markdown]
# # Graphing

# %%
df['Humidity'].value_counts().plot(kind='bar',figsize=(15,15))
plt.ylabel('Temperature')
plt.title('Humidity vs Temperature')
# plt.legend(['Does not have feathers','Has feathers'])
plt.show()
